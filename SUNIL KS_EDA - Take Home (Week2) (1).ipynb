# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Week2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Life Expectancy Data)
#
# The dataset contains the health data of 2938 individuals useful for predicting the life expentency of the individuals. The features are related to economical factors, immunity realted factors, social factors and so on.
#
# Attribute Information:
#
# **Country:** Country of the recorded data
#
# **Year:** Year of the recorded data
#
# **Status:** Status of the country
#
# **Life expectancy:** Life expectancy in age (target/dependent variable)
#
# **Adult mortality:** Rate of adult mortality
#
# **Infant deaths:** Number of Infant Deaths per 1000 population
#
# **Alcohol:** Alcohol consumption (in litres of pure alcohol)
#
# **Percentage expenditure:** Expenditure on health as a percentage of GDP
#
# **Hepatitis B:** Hepatitis B immunization coverage among 1-year-olds (%)
#
# **Measles:** Number of reported cases per 1000 population
#
# **BMI:** Average BMI of entire population
#
# **Under-five deaths:** Number of under-five deaths per 1000 population
#
# **Polio:** Polio immunization coverage among 1-year-olds (%)
#
# **Total expenditure:** Government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria:** DTP3 immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS:** Deaths per 1000 live births HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Thinness 1-19 years:** Prevalence of thinness for age 1 to 19 (%)
#
# **Thinness 5-9 years:** Prevalence of thinness for age 5 to 9 (%)
#
# **Income composition of resources:** Human Development Index in terms of income composition of resources
#
# **Schooling:** Number of years of Schooling

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the life expectancy dataset and print the first five observations

# %%
df_led=pd.read_csv('Life Expectancy Data.csv')
df_led.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Check the data type of each variable and if any variable is wrongly identified, do the needful</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_led.dtypes
df_led['Population'] = pd.to_numeric(df_led['Population'], errors = 'coerce')
df_led.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult mortality                    float64
# Infant deaths                        int64
# Alcohol                            float64
# Percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# Under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# Thinness  1-19 years               float64
# Thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
#Population column is initially defined under Object data type. But it should be numeric data type.
#So, it is now converted to float64 and we can perform numeric calculations on them.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Create a DataFrame containing the count and percentage of missing entries in each variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
Na_count = df_led.isnull().sum()
total = len(df_led)
per = round(Na_count / total *100, 2)
df_na_per = pd.DataFrame({'Count':Na_count, 'Percentage':per})
df_na_per
# Out:
#                                  Count  Percentage
# Country                              0        0.00
# Year                                 0        0.00
# Status                              16        0.54
# Life expectancy                     10        0.34
# Adult mortality                     10        0.34
# Infant deaths                        0        0.00
# Alcohol                            194        6.60
# Percentage expenditure               0        0.00
# Hepatitis B                        553       18.82
# Measles                              0        0.00
# BMI                                 34        1.16
# Under-five deaths                    0        0.00
# Polio                               19        0.65
# Total expenditure                  226        7.69
# Diphtheria                          19        0.65
# HIV/AIDS                             0        0.00
# GDP                                448       15.25
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3a. Are there any extreme values present in the government's total expenditure on health?
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(df_led['Total expenditure'])
plt.show()

# %%
#Yes. There are some extreme values present in the Government's total expenditure on health

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3b. Remove the outliers present in 'Total expenditure' using the quartiles of the variable
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
Q1 = df_led['Total expenditure'].quantile(.25)
Q2 = df_led['Total expenditure'].quantile(.5)
Q3 = df_led['Total expenditure'].quantile(.75)
IQR = Q3-Q1
new_df_led = df_led[~((df_led['Total expenditure'] < (Q1 - 1.5*IQR)) | (df_led['Total expenditure'] > (Q3 + 1.5*IQR)))]
sns.boxplot(df_led['Total expenditure'])
plt.show()
sns.boxplot(new_df_led['Total expenditure'])
plt.show()

# %%
#By using the IQR method, the outliers from the Total expenditure are removed and the new data frame is saved as new_df_led
#From the above box plots, we can see that, the outliers are removed considerably.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Split the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Hint:** 'Life expectancy' is the target variable depending on the remaining variables.

# %%
X = df_led.copy()
X.pop('Life expectancy')
y = df_led['Life expectancy'].to_frame()
X
# Out:
#           Country  Year      Status  Adult mortality  Infant deaths  Alcohol  \
# 0     Afghanistan  2015  Developing            263.0             62     0.01
# 1     Afghanistan  2014  Developing            271.0             64     0.01
# 2     Afghanistan  2013  Developing            268.0             66     0.01
# 3     Afghanistan  2012  Developing            272.0             69     0.01
# 4     Afghanistan  2011  Developing            275.0             71     0.01
# ...           ...   ...         ...              ...            ...      ...
# 2933     Zimbabwe  2004  Developing            723.0             27     4.36
# 2934     Zimbabwe  2003  Developing            715.0             26     4.06
# 2935     Zimbabwe  2002  Developing             73.0             25     4.43
# 2936     Zimbabwe  2001  Developing            686.0             25     1.72
# 2937     Zimbabwe  2000  Developing            665.0             24     1.68
#
# ...

# %%
y
# Out:
#       Life expectancy
# 0                65.0
# 1                59.9
# 2                59.9
# 3                59.5
# 4                59.2
# ...               ...
# 2933             44.3
# 2934             44.5
# 2935             44.8
# 2936             45.3
# 2937             46.0
#
# [2938 rows x 1 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Split the independent variables into two sets with the proportion of 70:30</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size = 0.3, random_state = 10)

print('Independent variable X train set', X_train.shape)
print('Independent variable X test set', X_test.shape)
# Out:
# Independent variable X train set (2056, 21)
# Independent variable X test set (882, 21)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. How would you treat the missing values in the variable 'GDP'?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print('Number of missing values in the variable GDP :',df_led['GDP'].isnull().sum())
print('Skewness before treating :',df_led['GDP'].skew())
sns.kdeplot(df_led['GDP'])
plt.show()
df_led['GDP'] = df_led['GDP'].fillna(df_led['GDP'].median())
print('Skewness after treating :',df_led['GDP'].skew())
sns.kdeplot(df_led['GDP'])
plt.show()
# Out:
# Number of missing values in the variable GDP : 448
# Skewness before treating : 3.2066548698696393
# Skewness after treating : 3.543755873452576

# %%
#Since the variable GDP is skewed, we fill the missing values with median.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7.There are 16 observations for which the status of the corresponding country is unknown, impute this status with an appropriate values</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Define a function to find the extreme values in alcohol consumption
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(df_led['Alcohol'])
plt.show()
Q1 = df_led['Alcohol'].quantile(.25)
Q2 = df_led['Alcohol'].quantile(.5)
Q3 = df_led['Alcohol'].quantile(.75)
IQR = Q3-Q1
new_df = df_led[((df_led['Alcohol'] < (Q1 - 1*IQR)) | (df_led['Alcohol'] > (Q3 + 1*IQR)))]
new_df
# Out:
#         Country  Year      Status  Life expectancy  Adult mortality  \
# 226     Belarus  2013  Developing             71.7             23.0
# 227     Belarus  2012  Developing             71.9            194.0
# 228     Belarus  2011  Developing             72.0            232.0
# 231     Belarus  2008  Developing             70.0            224.0
# 871     Estonia  2010  Developing             75.6            137.0
# 872     Estonia  2009  Developing             74.9            156.0
# 873     Estonia  2008  Developing             74.2            167.0
# 874     Estonia  2007  Developing             73.0            189.0
# 875     Estonia  2006  Developing             73.0            188.0
# 876     Estonia  2005  Developing             72.8            189.0
# 877     Estonia  2004  Developing             72.3            195.0
# 1523  Lithuania  2014   Developed             73.4            169.0
# 1524  Lithuania  2013   Developed             73.0            178.0
# ...

# %%
#Under standard condition of 1.5IQR, there are no outliers for Alcohol consumption as seen from the Box plot.
#But if we further reduce the IQR range to 1.0, then we can find 14 outliers in the Alcohol variable ranging from 14.66 to 15.14

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a column 'Life_expectancy_level' such that it will contain three levels (High, Medium, Low) based on the life expectancy </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
def new_cat(life_exp):
    if life_exp < 53:
        return 'Low'
    if ((life_exp > 53) & (life_exp < 70)):
        return 'Medium'
    if life_exp > 70:
        return 'High'

df_led['Life_expectancy_level'] = df_led['Life expectancy'].apply(new_cat)

df_led.sample(5)
# Out:
#                           Country  Year      Status  Life expectancy  \
# 1280                       Israel  2001  Developing             79.3
# 2157                       Rwanda  2009  Developing             61.0
# 2436                        Spain  2004   Developed             81.0
# 2782  United Republic of Tanzania  2011  Developing             58.3
# 1171                      Iceland  2014   Developed             82.5
#
#       Adult mortality  Infant deaths  Alcohol  Percentage expenditure  \
# 1280             74.0              1     2.53               22.273326
# 2157            288.0             17     7.11                9.165615
# 2436             79.0              2    11.96             3715.370095
# 2782            348.0             88     4.04                0.000000
# 1171             49.0              0     7.45             8254.020763
#
#       Hepatitis B  Measles  ...  Total expenditure  Diphtheria  HIV/AIDS  \
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Check how life expectancy has changed over the years in China</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_china = df_led[df_led['Country'] == 'China']
sns.lineplot(x='Year', y='Life expectancy', data=df_china, marker = 'o')
plt.show()
