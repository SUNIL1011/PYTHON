# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="images/R.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=6px>
#                     <b> NPV Mini Project
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ----
# # Employee Health Data
# ----

# %% [markdown]
# **A Company is having its offices across all locations of India. These locations are categorized with respect to zones.  The company has decided to give medical expenditure benefits to their employees.  The company has collected the medical expenditure of all the employees for the year 2019.  The company also collected some other health and family related data of all employees like number of dependents, age, bmi, smoking and alcoholic habits.**

# %% [markdown]
# <i><b>Answer the following questions to provide insight into the collected dat.</b></i>
#
# Dataset details **<br>
# id: Employee id - unique<br>
# age: age of primary beneficiary<br>
# sex: Gender data - female, male<br>
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,<br>
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9<br>
# dependent: Number of children other family members who are not earning and dependent on employee.<br>
# alcohol: Alcohol consumption habit. Possible values - daily, weekend, party, no, rarely<br>
# smoker: Smoking habit.<br>
# zone: The office location zones. Possible values - east, west, south, north, northeast, southeast, southwest, northwest.<br>
# expenditure: Individual medical expenditure by employees during year 2019<br>

# %% [markdown]
# ><b>IMPORT THE REQUIRED LIBRARIES</b>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# <b>  Read the dataset and do primary study of data. Perform following steps: </b>

# %%
data = pd.read_csv('C:/Users/admin/Downloads/NPV - Mini - Question-1/emp_health.csv')

# %% [markdown]
# >a. Reading some rows of dataset

# %%
data[2:10]
# Out:
#        id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 2  i10014   28    male  33.000          3   rarely    no      south
# 3  i10015   33    male  22.705          0    daily    no  northwest
# 4  i10016   32    male  28.880          0    party    no  northwest
# 5  i10017   31  female  25.740          0       no    no      south
# 6  i10018   46  female  33.440          1    daily    no      south
# 7  i10019   37  female  27.740          3  weekend    no  northwest
# 8  i10020   37    male  29.830          2    party    no      north
# 9  i10021   60  female  25.840          0       no    no  northwest
#
#    expenditure
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520
# 5   3756.62160
# 6   8240.58960
# 7   7281.50560
# 8   6406.41070
# 9  28923.13692

# %% [markdown]
# > b. Learn data types of all features

# %%
data.dtypes
# Out:
# id              object
# age              int64
# sex             object
# bmi            float64
# dependent        int64
# alcohol         object
# smoke           object
# zone            object
# expenditure    float64
# dtype: object

# %% [markdown]
# >c. See the statistical properties of the data.

# %%
data.describe()
# Out:
#                age          bmi    dependent   expenditure
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# <h3>Let's get started !!!</h3>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. How many employees above 50 age smoke, what is their average expenditure on health management?</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data[(data['smoke']=='yes') & (data['age']>50) ]['expenditure'].mean()
# Out:
# 38820.22308234375

# %% [markdown]
# employees above 50 age who smoke have average expenditure on health management as 38820.22308234375 .

# %%
data[(data['smoke']=='yes') & (data['age']>50)].count()
# Out:
# id             64
# age            64
# sex            64
# bmi            64
# dependent      64
# alcohol        64
# smoke          64
# zone           64
# expenditure    64
# dtype: int64

# %% [markdown]
#  64 many employees above 50 age smoke

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 2. How many female employees did not consume alcohol daily. What is their proportion with respect to total female employees?</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data[(data['alcohol']!='daily') & (data['sex']=='female')].count()
# Out:
# id             453
# age            453
# sex            453
# bmi            453
# dependent      453
# alcohol        453
# smoke          453
# zone           453
# expenditure    453
# dtype: int64

# %% [markdown]
# 453  female employees did not consume alcohol daily

# %%
data[data['sex']=='female'].count()
# Out:
# id             662
# age            662
# sex            662
# bmi            662
# dependent      662
# alcohol        662
# smoke          662
# zone           662
# expenditure    662
# dtype: int64

# %% [markdown]
# 662 are the total female employees

# %%
data_alcohol_female = data[(data['alcohol']!='daily') & (data['sex']=='female')].count()
data_female = data[data['sex']=='female'].count()
ratio = data_alcohol_female/data_female
ratio
# Out:
# id             0.68429
# age            0.68429
# sex            0.68429
# bmi            0.68429
# dependent      0.68429
# alcohol        0.68429
# smoke          0.68429
# zone           0.68429
# expenditure    0.68429
# dtype: float64

# %% [markdown]
# The ratio is  0.68429

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Display zone wise average expenditure of employees on health</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.DataFrame(data.groupby(['zone'])['expenditure'].mean())
# Out:
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872

# %% [markdown]
#  zone wise average expenditure of employees on health

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 4. Employees of which zone did maximum expenditure on health</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.DataFrame(data.groupby(['zone'])['expenditure'].sum())
# Out:
#             expenditure
# zone
# east       3.608966e+06
# north      9.871808e+05
# northeast  1.013409e+06
# northwest  1.761997e+06
# south      1.236118e+06
# southeast  2.861684e+06
# southwest  3.191988e+06
# west       3.094482e+06

# %%
zone_max_expenditure = pd.DataFrame(data.groupby(['zone'])['expenditure'].sum())
zone_max_expenditure
# Out:
#             expenditure
# zone
# east       3.608966e+06
# north      9.871808e+05
# northeast  1.013409e+06
# northwest  1.761997e+06
# south      1.236118e+06
# southeast  2.861684e+06
# southwest  3.191988e+06
# west       3.094482e+06

# %%
zone_max_expenditure.max()
# Out:
# expenditure    3.608966e+06
# dtype: float64

# %%
zone_max_expenditure[zone_max_expenditure['expenditure']==3608966.1444889996]
# Out:
#        expenditure
# zone
# east  3.608966e+06

# %%
zone_max_expenditure = pd.DataFrame(data.groupby(['zone'])['expenditure'].sum())
zone_max_expenditure
# Out:
#             expenditure
# zone
# east       3.608966e+06
# north      9.871808e+05
# northeast  1.013409e+06
# northwest  1.761997e+06
# south      1.236118e+06
# southeast  2.861684e+06
# southwest  3.191988e+06
# west       3.094482e+06

# %%
zone_max_expenditure.sort_values(['expenditure'],ascending = False).head(1)
# Out:
#        expenditure
# zone
# east  3.608966e+06

# %% [markdown]
# east zone did maximum expenditure on health.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. What is the minimum expenditure done by any employee in organization</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data['expenditure'].min()
# Out:
# 1121.8739

# %% [markdown]
# 1121.8739 is the minimum expenditure done by any employee in organization

# %%
data[data['expenditure']==data.expenditure.min()]
# Out:
#          id  age   sex    bmi  dependent alcohol smoke       zone  expenditure
# 940  i10952   18  male  23.21          0   party    no  southeast    1121.8739

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. What is average expenditure of employees who have 2 or lesser dependents</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data[data['dependent']<=2]['expenditure'].mean()
# Out:
# 13040.970970948145

# %% [markdown]
# 13040.970970948145 is the average expenditure of employees who have 2 or lesser dependents

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. How many employees are below age of 20 years. What is their average BMI</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data[data['age']<20].count()
# Out:
# id             137
# age            137
# sex            137
# bmi            137
# dependent      137
# alcohol        137
# smoke          137
# zone           137
# expenditure    137
# dtype: int64

# %% [markdown]
# 137 employees are below age of 20 years

# %%
data[data['age']<20]['bmi'].mean()
# Out:
# 29.971496350364966

# %% [markdown]
#  their average BMI is 29.971496350364966

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Create a dataframe "non_smoker" for all non-smoker male employees</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
non_smoker = data[(data['smoke']=='no') & (data['sex']=='male')] 
non_smoker
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
non_alcoholic = data[(data['alcohol']=='no') & (data['sex']=='male')] 
non_alcoholic
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 38    i10050   35  male  36.670          1      no   yes      north
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1291  i11303   19  male  34.900          0      no   yes  southwest
# 1301  i11313   62  male  30.875          3      no   yes       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 38    39774.27630
# ...           ...
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Create a dataframe called "non_smoking_alcoholic" with the men employees who do not smoke and consume alcohol. The dataframe should contain columns id, smoke, alcohol</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# > (Hint:Use join and dataframes created in Q8 and Q9)

# %%
non_smoking_alcoholic = pd.merge(non_smoker,non_alcoholic,on=['id','age','sex','alcohol','bmi','smoke','zone','dependent','expenditure'])
non_smoking_alcoholic[['id','smoke','alcohol']]
# Out:
#          id smoke alcohol
# 0    i10030    no      no
# 1    i10036    no      no
# 2    i10040    no      no
# 3    i10049    no      no
# 4    i10079    no      no
# ..      ...   ...     ...
# 104  i11273    no      no
# 105  i11282    no      no
# 106  i11322    no      no
# 107  i11332    no      no
# 108  i11345    no      no
#
# [109 rows x 3 columns]

# %%
non_smoking_alcoholic = pd.merge(non_smoker, non_alcoholic)
non_smoking_alcoholic[['id','smoke','alcohol']]
# Out:
#          id smoke alcohol
# 0    i10030    no      no
# 1    i10036    no      no
# 2    i10040    no      no
# 3    i10049    no      no
# 4    i10079    no      no
# ..      ...   ...     ...
# 104  i11273    no      no
# 105  i11282    no      no
# 106  i11322    no      no
# 107  i11332    no      no
# 108  i11345    no      no
#
# [109 rows x 3 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11.What is the count for each zone with respect to number of dependent</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.DataFrame(data.groupby(['zone'])['dependent'].value_counts())
# Out:
#                      dependent
# zone      dependent
# east      0                124
#           1                 65
#           2                 42
#           3                 22
#           4                  6
#           5                  3
# north     0                 26
#           1                 20
#           3                 12
#           2                 10
#           4                  1
#           5                  1
# northeast 0                 35
#           2                 15
#           3                 13
#           1                  9
#           4                  2
# northwest 0                 70
#           2                 30
#           1                 28
#           3                 13
#           4                  4
# south     0                 38
#           1                 21
#           2                 12
#           3                 12
#           4                  1
# southeast 0                 81
# ...

# %%
pd.DataFrame(data.groupby(['dependent','zone'])[['zone']].count())
# Out:
#                      zone
# dependent zone
# 0         east        124
#           north        26
#           northeast    35
#           northwest    70
#           south        38
#           southeast    81
#           southwest   116
#           west         84
# 1         east         65
#           north        20
#           northeast     9
#           northwest    28
#           south        21
#           southeast    57
#           southwest    53
#           west         71
# 2         east         42
#           north        10
#           northeast    15
#           northwest    30
#           south        12
#           southeast    38
#           southwest    44
#           west         49
# 3         east         22
#           north        12
#           northeast    13
#           northwest    13
#           south        12
#           southeast    15
#           southwest    25
#           west         45
# 4         east          6
#           north         1
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Classify the employees into 3 categories.</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# >Category 1 : employees below 18.5 bmi - underweight

# %%
underweight = pd.DataFrame(data[data['bmi'] < 18.5])
underweight
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 28    i10040   23    male  17.385          1       no    no  northwest
# 128   i10140   32  female  17.765          2  weekend   yes  northwest
# 172   i10184   18    male  15.960          0    party    no      north
# 198   i10210   51  female  18.050          0  weekend    no  northwest
# 232   i10244   19  female  17.800          0    party    no  southwest
# 250   i10262   18    male  17.290          2    party   yes      north
# 380   i10392   27  female  17.955          2    party   yes       east
# 410   i10422   19    male  17.480          0  weekend    no       west
# 412   i10424   26  female  17.195          2       no   yes       east
# 428   i10440   21  female  16.815          1    daily    no       east
# 680   i10692   21  female  17.400          1  weekend    no       west
# 821   i10833   26    male  17.670          0       no    no  northwest
# ...

# %% [markdown]
# > Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit

# %%
fit =  pd.DataFrame(data[(data['bmi']>=18.5) & (data['bmi']<=24.9)])
fit
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 15    i10027   19    male  24.600          1    party    no  southwest
# 17    i10029   23    male  23.845          0  weekend    no      north
# 26    i10038   63  female  23.085          0  weekend    no      north
# 35    i10047   19    male  20.425          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1304  i11316   42    male  24.605          2    daily   yes       east
# 1306  i11318   29  female  21.850          0  weekend   yes       east
# 1314  i11326   30  female  23.655          3    daily   yes       west
# 1316  i11328   19  female  20.600          0  weekend    no  southwest
# 1328  i11340   23  female  24.225          2  weekend    no       east
#
#       expenditure
# 3     21984.47061
# 15     1837.23700
# 17     2395.17155
# 26    14451.83515
# ...

# %% [markdown]
# > Category 3 : employee with bmi over 24.9 - overweight

# %%
overweight =  pd.DataFrame(data[data['bmi'] > 24.9])
overweight
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.90          0    daily   yes  southwest
# 1     i10013   18    male  33.77          1  weekend    no      south
# 2     i10014   28    male  33.00          3   rarely    no      south
# 4     i10016   32    male  28.88          0    party    no  northwest
# 5     i10017   31  female  25.74          0       no    no      south
# ...      ...  ...     ...    ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.97          3       no    no       west
# 1334  i11346   18  female  31.92          0    daily    no       east
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 0      16884.9240
# 1       1725.5523
# 2       4449.4620
# 4       3866.8552
# 5       3756.6216
# ...

# %% [markdown]
# >What is the average expenditure of employees in each category.

# %%
underweight_expenditure= underweight['expenditure'].mean()
underweight_expenditure
# Out:
# 8852.200585000002

# %% [markdown]
#  average expenditure of employees in  underweight category is 8852.200585000002

# %%
fit_expenditure = fit['expenditure'].mean()
fit_expenditure
# Out:
# 10379.499732162163

# %% [markdown]
# average expenditure of employees in  fit category is 10799.19392896153

# %%
overweight_expenditure = overweight['expenditure'].mean()
overweight_expenditure
# Out:
# 13936.616823466235

# %% [markdown]
# average expenditure of employees in  overweigh category is 13936.616823466235

# %% [markdown]
# >Display the bar chart for the same

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
BMI = ['overweight', 'fit', 'underweight']
AVG_EXPENDITURE = [overweight_expenditure, fit_expenditure, underweight_expenditure]
plt.title('BMI CATEGORY')
plt.xlabel('BMI')
plt.ylabel('AVG_EXPENDITURE')
plt.bar(BMI,AVG_EXPENDITURE)
plt.show()

# %%
conditions = [
    (data['bmi'] <= 18.5),
    (data['bmi'] >= 18.5) & (data['bmi'] <= 24.9),
    (data['bmi'] > 24.9)
    ]

values = ['underweight', 'fit', 'overweight']
data['categories']=np.select(conditions, values)

# %%
sns.barplot(x='categories',y='expenditure',data = data,estimator = np.mean, ci = 0 )
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Draw line plot of expenditure against age and BMI</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.lineplot(x='expenditure',y ='bmi',hue= 'age',data = data)
plt.show()

# %%
X = data['expenditure']
Y_age = data['age']
Y_bmi = data['bmi']

plt.plot( X,Y_age,'b', X,Y_bmi,'g')

plt.title('Line Plot')

plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Draw a bar chart to show zone wise average expenditure</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
zone_wise_avg_expenditure = pd.DataFrame(data.groupby(['zone'])['expenditure'].mean())
zone_wise_avg_expenditure
# Out:
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872

# %%
set(zone_wise_avg_expenditure['expenditure'])
# Out:
# {12151.702618758616,
#  12182.99887157481,
#  12717.083868764941,
#  13694.721723783787,
#  13774.679940797709,
#  14102.58340285714,
#  14452.949680454538,
#  14715.689519285717}

# %%
plt.figure(figsize=(20,10))
zone_wise_avg_expenditure.expenditure.plot(kind='bar', rot = 0)
plt.title('Bar Plot')

plt.xlabel('zone')


plt.ylabel('expenditure')


plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='zone',y='expenditure',data = data,estimator = np.mean, ci = 0 )
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 15. Draw a bar chart to show smoking and alcoholic habits against average expenditure</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
set(data['smoke'])
# Out:
# {'no', 'yes'}

# %%
set(data['alcohol'])
# Out:
# {'daily', 'no', 'party', 'rarely', 'weekend'}

# %%
sns.barplot(x = 'alcohol',y = 'expenditure',hue = 'smoke',data = data,estimator = np.mean, ci = 0)
plt.show()

# %%
sns.barplot(x = 'smoke',y = 'expenditure',hue = 'alcohol',data = data,estimator = np.mean, ci = 0)
plt.show()

# %%
data[['smoke','alcohol']].value_counts()
# Out:
# smoke  alcohol
# no     daily      316
#        weekend    286
#        party      221
#        no         197
# yes    daily       79
#        no          62
#        weekend     61
#        party       57
# no     rarely      44
# yes    rarely      15
# dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Draw pie chart for alcohol consumption habits</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data.alcohol.value_counts()
# Out:
# daily      395
# weekend    347
# party      278
# no         259
# rarely      59
# Name: alcohol, dtype: int64

# %%
 
plt.pie(data.alcohol.value_counts(), autopct = '%.2f%%', radius = 1.2, labels = ['daily', 'weekend ','party','no','rarely'])

plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
smoker = data[data['smoke']=='yes']
smoker
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 11    i10023   62  female  26.290          0    daily   yes      south
# 14    i10026   27    male  42.130          0  weekend   yes      south
# 19    i10031   30    male  35.300          0    daily   yes  southwest
# 23    i10035   34  female  31.920          1    party   yes      north
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1313  i11325   19  female  34.700          2    daily   yes  southwest
# 1314  i11326   30  female  23.655          3    daily   yes       west
# 1321  i11333   62    male  26.695          0    daily   yes       east
# 1323  i11335   42  female  40.370          2   rarely   yes  southeast
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 11    27808.72510
# 14    39611.75770
# 19    36837.46700
# ...

# %%
sns.scatterplot(data=data, x="age", y="expenditure", hue="smoke")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Draw distribution plot of expenditure</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.displot(data['expenditure'])
plt.title('Distribution plot of expenditure')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Display the pairplot</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize = (15,8))


sns.pairplot(data)


plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="images/question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Display heatmap for the data</b>
#                     <br>
#                  </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
#                   age       bmi  dependent  expenditure
# age          1.000000  0.109272   0.042469     0.299008
# bmi          0.109272  1.000000   0.012759     0.198341
# dependent    0.042469  0.012759   1.000000     0.067998
# expenditure  0.299008  0.198341   0.067998     1.000000

# %%
sns.heatmap(corr_matrix, annot = True )
plt.show()
